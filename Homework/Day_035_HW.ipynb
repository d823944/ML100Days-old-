# %% [markdown]
# ## 練習時間
# 相信大家對回歸問題及分類問題都有初步的了解。今天的作業希望大家搜尋有關 multi-label 的案例問題。下圖是電影 "奇異博士" 的分類。可以看到同時有 "Action", "Adventure", "Fantasy" 的類別存在，代表這是個多標籤的問題。

# %% [markdown]
# ![image](https://cdn-images-1.medium.com/max/1000/1*r0gYXMSQf5VhdMyl2bRDyg.png)

# %% [markdown]
# ## 請搜尋目標為多標籤問題 (Multi-label) 的機器學習案例，了解其資料來源、目標以及評估指標為何
# ## Hint: 服飾

# %% [markdown]
# ### **[Amazon](https://www.amazon.com/dp/1449369413/ref=pd_lpo_sbs_dp_ss_3?pf_rd_p=b4bbef4e-170e-463d-8538-7eff3394b224&pf_rd_s=lpo-top-stripe-1&pf_rd_t=201&pf_rd_i=1491962291&pf_rd_m=ATVPDKIKX0DER&pf_rd_r=ENY9Y564CDGQFBZMR88T&pf_rd_r=ENY9Y564CDGQFBZMR88T&pf_rd_p=b4bbef4e-170e-463d-8538-7eff3394b224)** is another example.
#
# A book is not only put on with one label, but can be classified into multiple categories. For example, the book "Introduction to Machine Learning with Python" can be found under the following three bins:
# - Books > Computers & Technology > Computer Science > AI & Machine Learning > Natural Language Processing
# - Books > Textbooks > Computer Science > Algorithms
# - Books > Computers & Technology > Programming > Algorithms

# %%
from IPython.display import Image
Image(filename = './book1.jpg', width=200)

# %%
Image(filename = './book2.png', width=800)
